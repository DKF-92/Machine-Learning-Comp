# %% [markdown]
# # Wine Quality Neural Network

# %%
# imports libraries, dependencies, ect..
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
# Drops unneeded ID column
df = df.drop(['Id'], axis=1)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
display(df.describe())
df['quality'].value_counts()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Exploratory Analysis

# %%
# Correlation Matrix
fig , ax = plt.subplots(figsize = (10,7))
sb.heatmap(df.corr() , annot = True , ax = ax)
plt.show()

# %% [markdown]
# ### Random Forest for feature importance

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=1, max_depth=12)
X = df.drop(['quality'], axis=1)
wd = pd.get_dummies(df)
model.fit(X, df.quality)
display(model.feature_importances_)
# Out:
# array([0.05632119, 0.12691137, 0.05034717, 0.04611758, 0.05600796,
#        0.04694396, 0.07254243, 0.05093393, 0.05573995, 0.13972943,
#        0.29840504])

# %%
features = wd.columns
importances = model.feature_importances_
indices = np.argsort(importances)[:]

plt.title('Rank of importance')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# removes three least important
del X['citric acid']
del X['free sulfur dioxide']
del X['residual sugar']

# %% [markdown]
# #### Encoding quality

# %%
le = LabelEncoder()
y = le.fit_transform(df.iloc[: , -1])
y = pd.DataFrame(y.reshape(len(y), 1))

# %% [markdown]
# ### SMOTE for data over sampling

# %%
from imblearn.over_sampling import SMOTE

strategy = {0:1700, 1:1700, 2:1700, 3:1700, 4:1700, 5:1700}
oversample = SMOTE(sampling_strategy=strategy)
X, y = oversample.fit_resample(X, y)

# %%
X.shape
# Out:
# (10200, 8)

# %% [markdown]
# ### Machine Learning model

# %%
# splits data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# quality to categorical dat
y_train_cat = tf.keras.utils.to_categorical(y_train, 6)
y_test_cat = tf.keras.utils.to_categorical(y_test, 6)

# %%
# scaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# #### Neural Network

# %%
nn = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=8,),
    tf.keras.layers.Dense(units=16, activation="relu"),
    tf.keras.layers.Dense(units=8, activation="relu"),
    tf.keras.layers.Dense(units=6, activation="sigmoid"),
])

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 6)                 54
#
# ...
# Total params: 334 (1.30 KB)
# Trainable params: 334 (1.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' ,metrics= ['accuracy'])

# %%
history = nn.fit(X_train, y_train_cat,  batch_size= 32, epochs = 150 , validation_data = (X_test, y_test_cat))
# Out:
# Epoch 1/150
# 255/255 [==============================] - 2s 3ms/step - loss: 1.6843 - accuracy: 0.2578 - val_loss: 1.4961 - val_accuracy: 0.3588
# Epoch 2/150
# 255/255 [==============================] - 1s 3ms/step - loss: 1.2968 - accuracy: 0.4674 - val_loss: 1.0631 - val_accuracy: 0.5735
# Epoch 3/150
# 255/255 [==============================] - 1s 2ms/step - loss: 1.0012 - accuracy: 0.5804 - val_loss: 0.9362 - val_accuracy: 0.6142
# Epoch 4/150
# 255/255 [==============================] - 1s 3ms/step - loss: 0.9209 - accuracy: 0.6118 - val_loss: 0.8688 - val_accuracy: 0.6368
# Epoch 5/150
# 255/255 [==============================] - 1s 3ms/step - loss: 0.8633 - accuracy: 0.6338 - val_loss: 0.8147 - val_accuracy: 0.6520
# Epoch 6/150
# 255/255 [==============================] - 1s 3ms/step - loss: 0.8254 - accuracy: 0.6466 - val_loss: 0.7835 - val_accuracy: 0.6647
# Epoch 7/150
# ...

# %%
plt.plot(history.history['loss'], label='MAE training data')
plt.plot(history.history['val_loss'], label='MAE validation data')
plt.legend()
plt.title('MAE for model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.savefig("MAE for Neural Network Model.png", bbox_inches='tight', dpi=300) # saves the plot
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Accuracy training data')
plt.plot(history.history['val_accuracy'], label='Accuracy validation data')
plt.legend()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.savefig("Neural Network Model Accuracy.png", bbox_inches='tight', dpi=300) # saves the plot
plt.show()
